# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on  `Settings`, `Utilities`, `Run_Experiments`, and `Run_Baselines` notebooks from the `the utils/` subfolder.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
import openai
import os
api_path = "C:\\Users\domin\Desktop\ETH\Capstone Project\API.txt"
with open(api_path, 'r') as api_file:
    api_key = api_file.read() 
openai.api_key = api_key

# %%
# %run utils/Settings.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/Utilities.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a shear modulus of  143.46 MPa within  20  development cycles.
# The Experiment is repeated  20  times using the  gpt-3.5-turbo  model and the prompt strategy:  terncontext .
# There are  3  combinations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Main Prompts</h2>'), Textarea(value='////You are a powerful ternary alloy predi…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_Experiments.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Tl, X = C
# The suggested combination achieved a shear modulus of 55 MPa
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Al, X = N
# The suggested combination achieved a shear modulus of 118 MPa
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Zr, A = Ga, X = S
# Iteration 3: No matching lab result found for suggestion {'M': 'Zr', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = Zr, A = Pb, X = N
# The suggested combination achieved a shear modulus of 61 MPa
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Ga, X = S
# Iteration 4: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = V, A = Ge, X = C
# The suggested combination achieved a shear modulus of 105 MPa
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = N
# The suggested combination achieved a shear modulus of 68 MPa
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = In, X = N
# No match found for suggestion string:  The combination is M = Mo, A = In, X = N
# Iteration 6: No matching lab result found for suggestion {'M': 'Mo', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = Nb, A = Si, X = N
# The suggested combination achieved a shear modulus of 103 MPa
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = In, X = C
# The suggested combination achieved a shear modulus of 83 MPa
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of 79 MPa
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = Sn, X = N
# The suggested combination achieved a shear modulus of 44 MPa
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = C
# The suggested combination achieved a shear modulus of 34 MPa
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Ga, X = N
# The suggested combination achieved a shear modulus of 102 MPa
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Al, X = C
# The suggested combination achieved a shear modulus of 116 MPa
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The formulation is M = W, A = Pb, X = N
# The suggested combination achieved a shear modulus of 47 MPa
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Ge, X = N
# The suggested combination achieved a shear modulus of 92 MPa
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Cd, X = N
# The suggested combination achieved a shear modulus of 84 MPa
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = C
# The suggested combination achieved a shear modulus of 64 MPa
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Tl, X = N
# The suggested combination achieved a shear modulus of 43 MPa
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = C
# The suggested combination achieved a shear modulus of 56 MPa
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of 88 MPa
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The formulation is M = V, A = Pb, X = C
# The suggested combination achieved a shear modulus of 63 MPa
# Data for experiment 1 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloycontext_prompt_experiment_1_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1731366319terncontext.csv.
#
# ---
# Starting experiment 2...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Tl, X = C
# The suggested combination achieved a shear modulus of 55 MPa
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Al, X = N
# The suggested combination achieved a shear modulus of 118 MPa
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Zr, A = Ga, X = S
# Iteration 3: No matching lab result found for suggestion {'M': 'Zr', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = Zr, A = Pb, X = N
# The suggested combination achieved a shear modulus of 61 MPa
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Ga, X = S
# Iteration 4: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = V, A = Ge, X = C
# The suggested combination achieved a shear modulus of 105 MPa
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = N
# The suggested combination achieved a shear modulus of 109 MPa
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of 67 MPa
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Sn, X = N
# Iteration 7: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Hf, A = Si, X = C
# The suggested combination achieved a shear modulus of 108 MPa
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of 60 MPa
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = As, X = N
# The suggested combination achieved a shear modulus of 74 MPa
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of 38 MPa
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Ga, X = C
# The suggested combination achieved a shear modulus of 101 MPa
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Al, X = N
# The suggested combination achieved a shear modulus of 112 MPa
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The formulation is M = W, A = Pb, X = N
# The suggested combination achieved a shear modulus of 47 MPa
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Sn, X = N
# The suggested combination achieved a shear modulus of 52 MPa
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Ge, X = C
# The suggested combination achieved a shear modulus of 113 MPa
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = In, X = C
# The suggested combination achieved a shear modulus of 98 MPa
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of 58 MPa
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Si, X = N
# The suggested combination achieved a shear modulus of 103 MPa
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The formulation is M = V, A = Pb, X = C
# The suggested combination achieved a shear modulus of 63 MPa
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = In, X = C
# The suggested combination achieved a shear modulus of 84 MPa
# Data for experiment 2 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloycontext_prompt_experiment_2_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1731366339terncontext.csv.
#
# ---
# Starting experiment 3...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = In, X = C
# The suggested combination achieved a shear modulus of 98 MPa
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = N
# The suggested combination achieved a shear modulus of 90 MPa
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Al, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Al, X = S
# Iteration 3: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Al', 'X': 'S'}
# Model Response:  The combination is M = V, A = Pb, X = C
# The suggested combination achieved a shear modulus of 63 MPa
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Al, X = S
# No match found for suggestion string:  The combination is M = Cr, A = Al, X = S
# Iteration 4: No matching lab result found for suggestion {'M': 'Cr', 'A': 'Al', 'X': 'S'}
# Model Response:  The combination is M = Hf, A = Si, X = N
# The suggested combination achieved a shear modulus of 99 MPa
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Al, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Al, X = S
# Iteration 5: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Al', 'X': 'S'}
# Model Response:  The combination is M = Cr, A = Tl, X = N
# The suggested combination achieved a shear modulus of 62 MPa
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Al, X = S
# No match found for suggestion string:  The combination is M = Mo, A = Al, X = S
# Iteration 6: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Al', 'X': 'S'}
# Model Response:  The combination is M = Nb, A = Ge, X = C
# The suggested combination achieved a shear modulus of 106 MPa
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Al, X = S
# No match found for suggestion string:  The combination is M = Mo, A = Al, X = S
# Iteration 7: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Al', 'X': 'S'}
# Model Response:  The combination is M = Ta, A = Al, X = N
# The suggested combination achieved a shear modulus of 115 MPa
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Sn, X = N
# Iteration 8: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of 38 MPa
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of 60 MPa
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = As, X = P
# No match found for suggestion string:  The combination is M = Sc, A = As, X = P
# Iteration 10: No matching lab result found for suggestion {'M': 'Sc', 'A': 'As', 'X': 'P'}
# Model Response:  The combination is M = Sc, A = As, X = C
# The suggested combination achieved a shear modulus of 66 MPa
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Sn, X = N
# The suggested combination achieved a shear modulus of 56 MPa
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = In, X = N
# No match found for suggestion string:  The combination is M = Mo, A = In, X = N
# Iteration 12: No matching lab result found for suggestion {'M': 'Mo', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = V, A = Ge, X = N
# The suggested combination achieved a shear modulus of 87 MPa
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = C
# The suggested combination achieved a shear modulus of 63 MPa
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The formulation is M = W, A = In, X = N
# No match found for suggestion string:  The combination is M = W, A = In, X = N
# Iteration 14: No matching lab result found for suggestion {'M': 'W', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = Cr, A = Pb, X = C
# The suggested combination achieved a shear modulus of 51 MPa
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The formulation is M = W, A = In, X = N
# No match found for suggestion string:  The combination is M = W, A = In, X = N
# Iteration 15: No matching lab result found for suggestion {'M': 'W', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = Hf, A = Pb, X = N
# The suggested combination achieved a shear modulus of 60 MPa
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The formulation is M = W, A = Al, X = N
# No match found for suggestion string:  The combination is M = W, A = Al, X = N
# Iteration 16: No matching lab result found for suggestion {'M': 'W', 'A': 'Al', 'X': 'N'}
# Model Response:  The combination is M = Zr, A = Cd, X = C
# The suggested combination achieved a shear modulus of 46 MPa
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The formulation is M = Al, A = In, X = N
# No match found for suggestion string:  The combination is M = Al, A = In, X = N
# Iteration 17: No matching lab result found for suggestion {'M': 'Al', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = Ti, A = S, X = C
# The suggested combination achieved a shear modulus of 134 MPa
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The formulation is M = W, A = Al, X = N
# No match found for suggestion string:  The combination is M = W, A = Al, X = N
# Iteration 18: No matching lab result found for suggestion {'M': 'W', 'A': 'Al', 'X': 'N'}
# Model Response:  The combination is M = W, A = As, X = N
# The suggested combination achieved a shear modulus of 70 MPa
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The formulation is M = Al, A = In, X = N
# No match found for suggestion string:  The combination is M = Al, A = In, X = N
# Iteration 19: No matching lab result found for suggestion {'M': 'Al', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = Ga, X = N
# The suggested combination achieved a shear modulus of 107 MPa
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The formulation is M = Al, A = In, X = N
# No match found for suggestion string:  The combination is M = Al, A = In, X = N
# Iteration 20: No matching lab result found for suggestion {'M': 'Al', 'A': 'In', 'X': 'N'}
# Model Response:  The combination is M = V, A = Ge, X = C
# The suggested combination achieved a shear modulus of 105 MPa
# Data for experiment 3 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloycontext_prompt_experiment_3_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1731366367terncontext.csv.
#
# ---
# Starting experiment 4...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Tl, X = C
# The suggested combination achieved a shear modulus of 55 MPa
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Al, X = N
# The suggested combination achieved a shear modulus of 118 MPa
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Zr, A = Ga, X = S
# Iteration 3: No matching lab result found for suggestion {'M': 'Zr', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = Zr, A = Pb, X = N
# The suggested combination achieved a shear modulus of 61 MPa
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Ga, X = S
# Iteration 4: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = V, A = Ge, X = C
# The suggested combination achieved a shear modulus of 105 MPa
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = N
# The suggested combination achieved a shear modulus of 109 MPa
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of 67 MPa
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Sn, X = N
# Iteration 7: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Hf, A = Si, X = C
# The suggested combination achieved a shear modulus of 108 MPa
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Sn, X = N
# Iteration 8: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 8: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Mo, A = As, X = N
# The suggested combination achieved a shear modulus of 75 MPa
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = Sn, X = N
# The suggested combination achieved a shear modulus of 44 MPa
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Cd, X = N
# The suggested combination achieved a shear modulus of 99 MPa
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Pb, X = C
# The suggested combination achieved a shear modulus of 77 MPa
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Al, X = N
# The suggested combination achieved a shear modulus of 112 MPa
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The formulation is M = W, A = In, X = C
# The suggested combination achieved a shear modulus of 76 MPa
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Ge, X = N
# The suggested combination achieved a shear modulus of 92 MPa
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = C
# The suggested combination achieved a shear modulus of 114 MPa
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Cd, X = N
# The suggested combination achieved a shear modulus of 84 MPa
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = C
# The suggested combination achieved a shear modulus of 63 MPa
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Si, X = N
# The suggested combination achieved a shear modulus of 103 MPa
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Sn, X = C
# The suggested combination achieved a shear modulus of 80 MPa
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The formulation is M = V, A = Pb, X = C
# The suggested combination achieved a shear modulus of 63 MPa
# Data for experiment 4 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloycontext_prompt_experiment_4_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1731366392terncontext.csv.
#
# ---
# Starting experiment 5...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Tl, X = C
# The suggested combination achieved a shear modulus of 55 MPa
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Al, X = N
# The suggested combination achieved a shear modulus of 118 MPa
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Zr, A = Ga, X = S
# Iteration 3: No matching lab result found for suggestion {'M': 'Zr', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = Zr, A = Pb, X = N
# The suggested combination achieved a shear modulus of 61 MPa
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = S
# No match found for suggestion string:  The combination is M = Nb, A = Ga, X = S
# Iteration 4: No matching lab result found for suggestion {'M': 'Nb', 'A': 'Ga', 'X': 'S'}
# Model Response:  The combination is M = V, A = Ge, X = C
# The suggested combination achieved a shear modulus of 105 MPa
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = N
# The suggested combination achieved a shear modulus of 68 MPa
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = C
# The suggested combination achieved a shear modulus of 99 MPa
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Sn, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Sn, X = N
# Iteration 7: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Hf, A = Si, X = N
# The suggested combination achieved a shear modulus of 99 MPa
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of 60 MPa
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20280\1407038887.py:181, in call_openai_api(messages, temp, max_retries, delay)
#     180 try:
# --> 181     response = openai.chat.completions.create(
#     182         model= model_dropdown.value,
#     183         temperature=temp,
#     184         messages=messages,
#     185         max_tokens=500,
#     186         n=1
#     187     )
#     188     return response
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\resources\chat\completions.py:704, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     703 validate_response_format(response_format)
# --> 704 return self._post(
#     705     "/chat/completions",
#     706     body=maybe_transform(
#     707         {
#     708             "messages": messages,
#     709             "model": model,
#     710             "frequency_penalty": frequency_penalty,
#     711             "function_call": function_call,
#     712             "functions": functions,
#     713             "logit_bias": logit_bias,
#     714             "logprobs": logprobs,
#     715             "max_completion_tokens": max_completion_tokens,
#     716             "max_tokens": max_tokens,
#     717             "n": n,
#     718             "parallel_tool_calls": parallel_tool_calls,
#     719             "presence_penalty": presence_penalty,
#     720             "response_format": response_format,
#     721             "seed": seed,
#     722             "service_tier": service_tier,
#     723             "stop": stop,
#     724             "stream": stream,
#     725             "stream_options": stream_options,
#     726             "temperature": temperature,
#     727             "tool_choice": tool_choice,
#     728             "tools": tools,
#     729             "top_logprobs": top_logprobs,
#     730             "top_p": top_p,
#     731             "user": user,
#     732         },
#     733         completion_create_params.CompletionCreateParams,
#     734     ),
#     735     options=make_request_options(
#     736         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     737     ),
#     738     cast_to=ChatCompletion,
#     739     stream=stream or False,
#     740     stream_cls=Stream[ChatCompletionChunk],
#     741 )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1267 opts = FinalRequestOptions.construct(
#    1268     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1269 )
# -> 1270 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     945     retries_taken = 0
# --> 947 return self._request(
#     948     cast_to=cast_to,
#     949     options=options,
#     950     stream=stream,
#     951     stream_cls=stream_cls,
#     952     retries_taken=retries_taken,
#     953 )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:983, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     982 try:
# --> 983     response = self._client.send(
#     984         request,
#     985         stream=stream or self._should_stream_response_body(request=request),
#     986         **kwargs,
#     987     )
#     988 except httpx.TimeoutException as err:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20280\4164685692.py:219
#     217     assistant_response = run_TVDL_strategy(system_message, training_data,tested_formulations, iterate_prompt.value,context_prompt.value, VM_role_prompt.value, conversation_dropdown,enable_TVDL_strategy)
#     218 else:
# --> 219     response = call_openai_api(messages, temp)
#     220     assistant_response = response.choices[0].message
#     222 if assistant_response.role == "assistant":
#
# File ~\AppData\Local\Temp\ipykernel_20280\1407038887.py:189, in call_openai_api(messages, temp, max_retries, delay)
#     181     response = openai.chat.completions.create(
#     182         model= model_dropdown.value,
#     183         temperature=temp,
#    (...)
#     186         n=1
#     187     )
#     188     return response
# --> 189 except openai.error.OpenAIError as e:
#     191     handle_openai_error(e)
#     192     if i < max_retries - 1:  # i is zero indexed
#
# AttributeError: module 'openai' has no attribute 'error'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20280\1407038887.py:181, in call_openai_api(messages, temp, max_retries, delay)
#     180 try:
# --> 181     response = openai.chat.completions.create(
#     182         model= model_dropdown.value,
#     183         temperature=temp,
#     184         messages=messages,
#     185         max_tokens=500,
#     186         n=1
#     187     )
#     188     return response
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\resources\chat\completions.py:704, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     703 validate_response_format(response_format)
# --> 704 return self._post(
#     705     "/chat/completions",
#     706     body=maybe_transform(
#     707         {
#     708             "messages": messages,
#     709             "model": model,
#     710             "frequency_penalty": frequency_penalty,
#     711             "function_call": function_call,
#     712             "functions": functions,
#     713             "logit_bias": logit_bias,
#     714             "logprobs": logprobs,
#     715             "max_completion_tokens": max_completion_tokens,
#     716             "max_tokens": max_tokens,
#     717             "n": n,
#     718             "parallel_tool_calls": parallel_tool_calls,
#     719             "presence_penalty": presence_penalty,
#     720             "response_format": response_format,
#     721             "seed": seed,
#     722             "service_tier": service_tier,
#     723             "stop": stop,
#     724             "stream": stream,
#     725             "stream_options": stream_options,
#     726             "temperature": temperature,
#     727             "tool_choice": tool_choice,
#     728             "tools": tools,
#     729             "top_logprobs": top_logprobs,
#     730             "top_p": top_p,
#     731             "user": user,
#     732         },
#     733         completion_create_params.CompletionCreateParams,
#     734     ),
#     735     options=make_request_options(
#     736         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     737     ),
#     738     cast_to=ChatCompletion,
#     739     stream=stream or False,
#     740     stream_cls=Stream[ChatCompletionChunk],
#     741 )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1267 opts = FinalRequestOptions.construct(
#    1268     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1269 )
# -> 1270 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     945     retries_taken = 0
# --> 947 return self._request(
#     948     cast_to=cast_to,
#     949     options=options,
#     950     stream=stream,
#     951     stream_cls=stream_cls,
#     952     retries_taken=retries_taken,
#     953 )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\openai\_base_client.py:983, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     982 try:
# --> 983     response = self._client.send(
#     984         request,
#     985         stream=stream or self._should_stream_response_body(request=request),
#     986         **kwargs,
#     987     )
#     988 except httpx.TimeoutException as err:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_line_magic('run', 'utils/Run_Experiments.ipynb')
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File c:\Users\domin\anaconda3\envs\capstoneproject\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_20280\4164685692.py:219
#     217     assistant_response = run_TVDL_strategy(system_message, training_data,tested_formulations, iterate_prompt.value,context_prompt.value, VM_role_prompt.value, conversation_dropdown,enable_TVDL_strategy)
#     218 else:
# --> 219     response = call_openai_api(messages, temp)
#     220     assistant_response = response.choices[0].message
#     222 if assistant_response.role == "assistant":
#
# File ~\AppData\Local\Temp\ipykernel_20280\1407038887.py:189, in call_openai_api(messages, temp, max_retries, delay)
#     181     response = openai.chat.completions.create(
#     182         model= model_dropdown.value,
#     183         temperature=temp,
#    (...)
#     186         n=1
#     187     )
#     188     return response
# --> 189 except openai.error.OpenAIError as e:
#     191     handle_openai_error(e)
#     192     if i < max_retries - 1:  # i is zero indexed
#
# AttributeError: module 'openai' has no attribute 'error'

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Run_Baselines.ipynb
# Out:
# Experiment: 1
# Experiment: 2
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 3
# Experiment: 4
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 5
# Experiment: 6
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/_gpr.py:659: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 7
# Experiment: 8
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 9
# Experiment: 10
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 11
# Experiment: 12
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 13
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 14
# Experiment: 15
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 16
# Experiment: 17
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 23
# Experiment: 24
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 25
# Experiment: 26
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 27
# Experiment: 28
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 29
# Experiment: 30
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
