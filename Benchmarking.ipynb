# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on  `Settings`, `Utilities`, `Run_Experiments`, and `Run_Baselines` notebooks from the `the utils/` subfolder.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
import openai
import os
api_path = "C:\\Users\domin\Desktop\ETH\Capstone Project\API.txt"
with open(api_path, 'r') as api_file:
    api_key = api_file.read() 
openai.api_key = api_key

# %%
# %run utils/Settings.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/Utilities.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a performance of  64.86370000000001 within  20  development cycles.
# The Experiment is repeated  15  times using the  gpt-3.5-turbo  model and the prompt strategy:  zero .
# There are  3  combinations above or equal to desired_strength.
# C:\Users\domin\AppData\Local\Temp\ipykernel_19520\3264990276.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   formulation_df = pd.concat([formulation_df, new_row], ignore_index=True)
# VBox(children=(HTML(value='<h2>Main Prompts</h2>'), Textarea(value="////You are a prediction model tasked with…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_Experiments.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.37
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.96
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.86
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.43
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  57.54
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  'The combination is A = 380, B = 0.45, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.45, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.45', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 380, B = 0.5, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.5, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.5', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 380, B = 0.5, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.5, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.5', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  The combination is A = 380, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  60.47
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  32.12
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.68
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  48.47
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  51.07
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.85
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.77
# Data for experiment 1 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_1_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291206zero.csv.
#
# ---
# Starting experiment 2...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.37
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.96
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.86
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.43
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  40.78
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  60.47
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  'The combination is A = 450, B = 0.55, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.55, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.55', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  'The formulation is A = 390, B = 0.55, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 1'
# Iteration 14: No matching lab result found for suggestion {'A': '390', 'B': '0.55', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '390', 'B': '0.55', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.6
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  54.38
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  'The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 0'
# Iteration 16: No matching lab result found for suggestion {'A': '390', 'B': '0.55', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The formulation is A = 410, B = 0.55, C = 0.5/0.5, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.55, C = 0.5/0.5, D = 1'
# Iteration 16: No matching lab result found for suggestion {'A': '410', 'B': '0.55', 'C': '0.5/0.5', 'D': "1'"}
# Model Response:  The combination is A = 410, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  51.07
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  'The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1'
# Iteration 17: No matching lab result found for suggestion {'A': '420', 'B': '0.5', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The formulation is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# Iteration 17: No matching lab result found for suggestion {'A': '390', 'B': '0.6', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# Iteration 17: No matching lab result found for suggestion {'A': '390', 'B': '0.6', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# Iteration 17: No matching lab result found for suggestion {'A': '390', 'B': '0.6', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The formulation is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# Iteration 17: No matching lab result found for suggestion {'A': '390', 'B': '0.6', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  'The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1'
# Iteration 18: No matching lab result found for suggestion {'A': '420', 'B': '0.5', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  The combination is A = 420, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.22
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  36.52
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  'The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 0'
# Iteration 20: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The formulation is A = 380, B = 0.55, C = 0.5/0.5, D = 1'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.5/0.5, D = 1'
# Iteration 20: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.5/0.5', 'D': "1'"}
# Model Response:  The combination is A = 380, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.88
# Data for experiment 2 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_2_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291234zero.csv.
#
# ---
# Starting experiment 3...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  33.03
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.6
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  60.68
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  56.66
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  46.48
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.38
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  53.05
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  29.46
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.43
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  'The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1'
# Iteration 15: No matching lab result found for suggestion {'A': '410', 'B': '0.45', 'C': '0.5/0.5', 'D': "1'"}
# Model Response:  'The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1'
# Iteration 15: No matching lab result found for suggestion {'A': '410', 'B': '0.45', 'C': '0.5/0.5', 'D': "1'"}
# Model Response:  The combination is A = 420, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.8
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  56.62
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.88
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.89
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.17
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.93
# Data for experiment 3 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_3_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291253zero.csv.
#
# ---
# Starting experiment 4...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.77
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.45, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.08
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.72
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.0
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  39.8
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.27
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  29.46
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  55.62
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.35
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.22
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  'The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 0'
# Iteration 18: No matching lab result found for suggestion {'A': '380', 'B': '0.55', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  'The formulation is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# No match found for suggestion string:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0'
# Iteration 18: No matching lab result found for suggestion {'A': '390', 'B': '0.6', 'C': '0.7/0.3', 'D': "0'"}
# Model Response:  The combination is A = 390, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.03
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  29.43
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
# Data for experiment 4 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_4_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291271zero.csv.
#
# ---
# Starting experiment 5...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  35.2
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  46.84
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.16
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.03
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.03
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  46.48
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.15
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  'The combination is A = 410, B = 0.45, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.45, C = 0.7/0.3, D = 1'
# Iteration 16: No matching lab result found for suggestion {'A': '410', 'B': '0.45', 'C': '0.7/0.3', 'D': "1'"}
# Model Response:  'The combination is A = 410, B = 0.55, C = 0.6/0.4, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.55, C = 0.6/0.4, D = 1'
# Iteration 16: No matching lab result found for suggestion {'A': '410', 'B': '0.55', 'C': '0.6/0.4', 'D': "1'"}
# Model Response:  'The combination is A = 410, B = 0.55, C = 0.6/0.4, D = 1'
# No match found for suggestion string:  The combination is A = 410, B = 0.55, C = 0.6/0.4, D = 1'
# Iteration 16: No matching lab result found for suggestion {'A': '410', 'B': '0.55', 'C': '0.6/0.4', 'D': "1'"}
# Model Response:  The combination is A = 370, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  33.49
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.29
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.43
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.35
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.11
# Data for experiment 5 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_5_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291291zero.csv.
#
# ---
# Starting experiment 6...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.68
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.72
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  48.14
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  57.54
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  48.75
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  40.78
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.93
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  38.63
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.16
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.45, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.48
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.3
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.89
# Data for experiment 6 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_6_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291309zero.csv.
#
# ---
# Starting experiment 7...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.68
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  63.47
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  37.52
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  48.75
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  44.49
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.77
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  49.86
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.5
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  48.47
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.5
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  59.73
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  39.8
# Data for experiment 7 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_7_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291326zero.csv.
#
# ---
# Starting experiment 8...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.68
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  60.18
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.64
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  45.75
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  40.78
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  59.88
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  44.49
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.37
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.6, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.5
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.45, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.08
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  33.03
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.73
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  46.84
# Data for experiment 8 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_8_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291343zero.csv.
#
# ---
# Starting experiment 9...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  32.59
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  56.36
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.2
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.64
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.88
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  20.76
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.8
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.2
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  61.22
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.03
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  49.59
# Data for experiment 9 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_9_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291361zero.csv.
#
# ---
# Starting experiment 10...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  35.2
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  55.62
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.16
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.13
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  23.62
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.75
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.64
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  20.76
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  58.24
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  42.72
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.84
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.89
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  60.18
# Data for experiment 10 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_10_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291377zero.csv.
#
# ---
# Starting experiment 11...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  35.2
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  55.62
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.16
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.13
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  23.62
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.75
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.15
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  'The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.5', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  'The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.5', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  The combination is A = 450, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  58.53
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  58.93
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  'The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 1'
# No match found for suggestion string:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 1'
# ...
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  35.2
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.43
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.01
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  55.62
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  38.16
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.13
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  23.62
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.45, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.75
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  49.86
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  'The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.5', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  'The formulation is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.5', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  'The formulation is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# No match found for suggestion string:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.5', 'C': '0.6/0.4', 'D': "0'"}
# Model Response:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  28.3
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  50.64
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  58.24
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.03
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  61.95
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.11
# Data for experiment 12 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_12_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291418zero.csv.
#
# ---
# Starting experiment 13...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  26.89
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.03
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.5
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  'The combination is A = 430, B = 0.45, C = 0.5/0.5, D = 1'
# No match found for suggestion string:  The combination is A = 430, B = 0.45, C = 0.5/0.5, D = 1'
# Iteration 13: No matching lab result found for suggestion {'A': '430', 'B': '0.45', 'C': '0.5/0.5', 'D': "1'"}
# Model Response:  The combination is A = 370, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  46.84
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  'The combination is A = 450, B = 0.45, C = 0.6/0.4, D = 1'
# No match found for suggestion string:  The combination is A = 450, B = 0.45, C = 0.6/0.4, D = 1'
# Iteration 14: No matching lab result found for suggestion {'A': '450', 'B': '0.45', 'C': '0.6/0.4', 'D': "1'"}
# Model Response:  The combination is A = 430, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  56.66
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  29.46
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.35
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  36.52
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.19
# Data for experiment 13 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_13_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291438zero.csv.
#
# ---
# Starting experiment 14...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  26.89
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  32.58
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.5
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  56.66
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  29.46
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  60.28
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.5, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  36.52
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.4
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.89
# Data for experiment 14 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_14_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291456zero.csv.
#
# ---
# Starting experiment 15...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The combination is A = 360, B = 0.45, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  33.83
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The combination is A = 440, B = 0.6, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  52.42
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.5, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  59.03
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The combination is A = 410, B = 0.55, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  26.95
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  50.69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.45, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  41.34
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.6, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  47.28
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.5, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  51.04
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.5, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  43.5
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The combination is A = 390, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.73
#
# ---
# Starting iteration 11 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.5
#
# ---
# Starting iteration 12 at temp 0.0...
# Model Response:  The combination is A = 400, B = 0.55, C = 0.6/0.4, D = 1
# The suggested combination achieved a performance of  57.12
#
# ---
# Starting iteration 13 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.45, C = 0.5/0.5, D = 1
# The suggested combination achieved a performance of  54.97
#
# ---
# Starting iteration 14 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.6, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  27.77
#
# ---
# Starting iteration 15 at temp 0.0...
# Model Response:  'The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 0'
# No match found for suggestion string:  The combination is A = 420, B = 0.55, C = 0.5/0.5, D = 0'
# Iteration 15: No matching lab result found for suggestion {'A': '420', 'B': '0.55', 'C': '0.5/0.5', 'D': "0'"}
# Model Response:  The combination is A = 410, B = 0.5, C = 0.5/0.5, D = 0
# The suggested combination achieved a performance of  60.28
#
# ---
# Starting iteration 16 at temp 0.0...
# Model Response:  The combination is A = 420, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  44.67
#
# ---
# Starting iteration 17 at temp 0.0...
# Model Response:  The combination is A = 370, B = 0.6, C = 0.7/0.3, D = 0
# The suggested combination achieved a performance of  25.6
#
# ---
# Starting iteration 18 at temp 0.0...
# Model Response:  The combination is A = 430, B = 0.45, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.01
#
# ---
# Starting iteration 19 at temp 0.0...
# Model Response:  The combination is A = 380, B = 0.55, C = 0.6/0.4, D = 0
# The suggested combination achieved a performance of  46.12
#
# ---
# Starting iteration 20 at temp 0.0...
# Model Response:  The combination is A = 450, B = 0.55, C = 0.7/0.3, D = 1
# The suggested combination achieved a performance of  35.2
# Data for experiment 15 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_ZeroContext_prompt_experiment_15_temp_0.0_target_99_%_Dev_Budget_20_recursive_0_1730291473zero.csv.

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Run_Baselines.ipynb
# Out:
# Experiment: 1
# Experiment: 2
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 3
# Experiment: 4
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 5
# Experiment: 6
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/_gpr.py:659: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 7
# Experiment: 8
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 9
# Experiment: 10
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 11
# Experiment: 12
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 13
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 14
# Experiment: 15
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 16
# Experiment: 17
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 23
# Experiment: 24
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 25
# Experiment: 26
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 27
# Experiment: 28
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 29
# Experiment: 30
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
