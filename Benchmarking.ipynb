# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on  `Settings`, `Utilities`, `Run_Experiments`, and `Run_Baselines` notebooks from the `the utils/` subfolder.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
import openai
import os
api_path = "C:\\Users\manue\Downloads\capstone_api.txt"
with open(api_path, 'r') as api_file:
    api_key = api_file.read() 
openai.api_key = api_key

# %%
# %run utils/Settings.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/Utilities.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a shear modulus of  143.46 MPa within  10  development cycles.
# The Experiment is repeated  15  times using the  gpt-3.5-turbo  model and the prompt strategy:  ternary .
# There are  3  combinations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Main Prompts</h2>'), Textarea(value='////You are a powerful ternary alloy predi…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_Experiments.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Si, X = N
# The suggested combination achieved a shear modulus of  49
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  88
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = In, X = N
# The suggested combination achieved a shear modulus of  80
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Pb, X = C
# The suggested combination achieved a shear modulus of  69
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Cd, X = N
# The suggested combination achieved a shear modulus of  84
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = N
# The suggested combination achieved a shear modulus of  70
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Ge, X = N
# The suggested combination achieved a shear modulus of  92
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Al, X = N
# The suggested combination achieved a shear modulus of  109
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Sn, X = C
# The suggested combination achieved a shear modulus of  63
# Data for experiment 1 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_1_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451763ternary.csv.
#
# ---
# Starting experiment 2...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ga, X = N
# The suggested combination achieved a shear modulus of  109
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = In, X = C
# The suggested combination achieved a shear modulus of  84
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Pb, X = N
# The suggested combination achieved a shear modulus of  30
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ge, X = N
# The suggested combination achieved a shear modulus of  53
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Tl, X = N
# The suggested combination achieved a shear modulus of  78
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = W, A = Al, X = N
# No match found for suggestion string:  The combination is M = W, A = Al, X = N
# Iteration 8: No matching lab result found for suggestion {'M': 'W', 'A': 'Al', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = Al, X = C
# The suggested combination achieved a shear modulus of  122
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = As, X = N
# The suggested combination achieved a shear modulus of  57
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 10: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
# Data for experiment 2 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_2_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451771ternary.csv.
#
# ---
# Starting experiment 3...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  114
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = N
# The suggested combination achieved a shear modulus of  94
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of  79
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = As, X = N
# The suggested combination achieved a shear modulus of  74
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
# Data for experiment 3 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_3_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451778ternary.csv.
#
# ---
# Starting experiment 4...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = C
# The suggested combination achieved a shear modulus of  108
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of  67
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Tl, X = N
# The suggested combination achieved a shear modulus of  81
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Ge, X = N
# The suggested combination achieved a shear modulus of  87
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Al, X = N
# The suggested combination achieved a shear modulus of  115
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = N
# The suggested combination achieved a shear modulus of  70
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Sn, X = C
# The suggested combination achieved a shear modulus of  63
# Data for experiment 4 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_4_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451784ternary.csv.
#
# ---
# Starting experiment 5...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Si, X = N
# The suggested combination achieved a shear modulus of  49
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  88
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = In, X = N
# The suggested combination achieved a shear modulus of  80
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Pb, X = N
# The suggested combination achieved a shear modulus of  30
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = N
# The suggested combination achieved a shear modulus of  94
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = W, A = Tl, X = C
# The suggested combination achieved a shear modulus of  57
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = As, X = N
# The suggested combination achieved a shear modulus of  74
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Sn, X = N
# The suggested combination achieved a shear modulus of  76
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = C
# The suggested combination achieved a shear modulus of  57
# Data for experiment 5 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_5_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451790ternary.csv.
#
# ---
# Starting experiment 6...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Si, X = N
# The suggested combination achieved a shear modulus of  49
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  88
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = In, X = N
# The suggested combination achieved a shear modulus of  80
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Pb, X = N
# The suggested combination achieved a shear modulus of  30
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = N
# The suggested combination achieved a shear modulus of  94
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = As, X = C
# The suggested combination achieved a shear modulus of  129
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Tl, X = N
# The suggested combination achieved a shear modulus of  78
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Al, X = C
# The suggested combination achieved a shear modulus of  110
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Sn, X = N
# The suggested combination achieved a shear modulus of  75
# Data for experiment 6 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_6_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451797ternary.csv.
#
# ---
# Starting experiment 7...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  114
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = N
# The suggested combination achieved a shear modulus of  94
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of  79
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = C
# The suggested combination achieved a shear modulus of  57
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = As, X = N
# The suggested combination achieved a shear modulus of  74
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 10: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
# Data for experiment 7 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_7_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451803ternary.csv.
#
# ---
# Starting experiment 8...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = C
# The suggested combination achieved a shear modulus of  108
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of  67
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Tl, X = N
# The suggested combination achieved a shear modulus of  81
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Ge, X = N
# The suggested combination achieved a shear modulus of  87
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Al, X = N
# The suggested combination achieved a shear modulus of  115
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = As, X = C
# The suggested combination achieved a shear modulus of  66
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 10: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 10: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
# Data for experiment 8 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_8_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451810ternary.csv.
#
# ---
# Starting experiment 9...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ga, X = N
# The suggested combination achieved a shear modulus of  109
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of  67
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ge, X = N
# The suggested combination achieved a shear modulus of  91
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = As, X = N
# The suggested combination achieved a shear modulus of  114
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = W, A = Tl, X = N
# The suggested combination achieved a shear modulus of  56
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = S, X = C
# The suggested combination achieved a shear modulus of  95
# Data for experiment 9 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_9_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451817ternary.csv.
#
# ---
# Starting experiment 10...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ga, X = C
# The suggested combination achieved a shear modulus of  108
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = In, X = N
# The suggested combination achieved a shear modulus of  67
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Cd, X = N
# The suggested combination achieved a shear modulus of  84
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Ge, X = N
# The suggested combination achieved a shear modulus of  87
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Al, X = N
# The suggested combination achieved a shear modulus of  115
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = C
# The suggested combination achieved a shear modulus of  34
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Sn, X = N
# The suggested combination achieved a shear modulus of  75
# Data for experiment 10 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_10_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451823ternary.csv.
#
# ---
# Starting experiment 11...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = N
# The suggested combination achieved a shear modulus of  68
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Pb, X = C
# The suggested combination achieved a shear modulus of  71
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = C
# The suggested combination achieved a shear modulus of  106
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = N
# The suggested combination achieved a shear modulus of  70
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of  79
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Sn, X = C
# The suggested combination achieved a shear modulus of  81
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = N
# The suggested combination achieved a shear modulus of  77
# Data for experiment 11 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_11_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451829ternary.csv.
#
# ---
# Starting experiment 12...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ga, X = N
# The suggested combination achieved a shear modulus of  109
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = In, X = C
# The suggested combination achieved a shear modulus of  84
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Pb, X = N
# The suggested combination achieved a shear modulus of  39
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Ge, X = N
# The suggested combination achieved a shear modulus of  91
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of  79
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = As, X = N
# The suggested combination achieved a shear modulus of  75
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Tl, X = C
# The suggested combination achieved a shear modulus of  55
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = Ta, A = Sn, X = C
# The suggested combination achieved a shear modulus of  81
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = Al, X = N
# No match found for suggestion string:  The combination is M = W, A = Al, X = N
# Iteration 10: No matching lab result found for suggestion {'M': 'W', 'A': 'Al', 'X': 'N'}
# Model Response:  The combination is M = W, A = Al, X = C
# The suggested combination achieved a shear modulus of  110
# Data for experiment 12 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_12_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451837ternary.csv.
#
# ---
# Starting experiment 13...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Si, X = N
# The suggested combination achieved a shear modulus of  49
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  88
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = In, X = N
# The suggested combination achieved a shear modulus of  80
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = Pb, X = N
# The suggested combination achieved a shear modulus of  30
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = N
# The suggested combination achieved a shear modulus of  94
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Cd, X = N
# The suggested combination achieved a shear modulus of  60
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = As, X = C
# The suggested combination achieved a shear modulus of  129
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Tl, X = N
# The suggested combination achieved a shear modulus of  78
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = N
# The suggested combination achieved a shear modulus of  77
# Data for experiment 13 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_13_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451844ternary.csv.
#
# ---
# Starting experiment 14...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Si, X = N
# The suggested combination achieved a shear modulus of  49
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  88
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = V, A = Cd, X = N
# The suggested combination achieved a shear modulus of  95
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Pb, X = C
# The suggested combination achieved a shear modulus of  73
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Ge, X = N
# No match found for suggestion string:  The combination is M = Mo, A = Ge, X = N
# Iteration 6: No matching lab result found for suggestion {'M': 'Mo', 'A': 'Ge', 'X': 'N'}
# Model Response:  The combination is M = Mo, A = Tl, X = N
# The suggested combination achieved a shear modulus of  58
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = W, A = Ge, X = N
# No match found for suggestion string:  The combination is M = W, A = Ge, X = N
# Iteration 7: No matching lab result found for suggestion {'M': 'W', 'A': 'Ge', 'X': 'N'}
# Model Response:  The combination is M = Hf, A = Al, X = C
# The suggested combination achieved a shear modulus of  105
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = Ge, X = N
# The suggested combination achieved a shear modulus of  92
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = W, A = Sn, X = N
# No match found for suggestion string:  The combination is M = W, A = Sn, X = N
# Iteration 9: No matching lab result found for suggestion {'M': 'W', 'A': 'Sn', 'X': 'N'}
# Model Response:  The combination is M = W, A = Sn, X = C
# The suggested combination achieved a shear modulus of  38
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = As, X = N
# The suggested combination achieved a shear modulus of  57
# Data for experiment 14 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_14_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451852ternary.csv.
#
# ---
# Starting experiment 15...
# ---
# SFDL
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is M = V, A = Si, X = N
# The suggested combination achieved a shear modulus of  102
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is M = Cr, A = Ga, X = C
# The suggested combination achieved a shear modulus of  114
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is M = Nb, A = In, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is M = Mo, A = Pb, X = C
# The suggested combination achieved a shear modulus of  35
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is M = Zr, A = Tl, X = N
# The suggested combination achieved a shear modulus of  69
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is M = Ti, A = Ge, X = C
# The suggested combination achieved a shear modulus of  106
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is M = Hf, A = Cd, X = N
# The suggested combination achieved a shear modulus of  79
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is M = Ta, A = S, X = C
# The suggested combination achieved a shear modulus of  95
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is M = Sc, A = Al, X = N
# The suggested combination achieved a shear modulus of  77
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is M = W, A = As, X = N
# The suggested combination achieved a shear modulus of  70
# Data for experiment 15 and temp 0.0 successfully saved to Results/LLM/gpt-3.5-turbo_TernaryAlloy_prompt_experiment_15_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1730451858ternary.csv.

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Run_Baselines.ipynb
# Out:
# Experiment: 1
# Experiment: 2
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 3
# Experiment: 4
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 5
# Experiment: 6
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/_gpr.py:659: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 7
# Experiment: 8
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 9
# Experiment: 10
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 11
# Experiment: 12
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 13
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 14
# Experiment: 15
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 16
# Experiment: 17
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 23
# Experiment: 24
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 25
# Experiment: 26
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 27
# Experiment: 28
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 29
# Experiment: 30
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /Users/christophvoelker/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
# Experiment: 1
# Experiment: 2
# Experiment: 3
# Experiment: 4
# Experiment: 5
# Experiment: 6
# Experiment: 7
# Experiment: 8
# Experiment: 9
# Experiment: 10
# Experiment: 11
# Experiment: 12
# Experiment: 13
# Experiment: 14
# Experiment: 15
# Experiment: 16
# Experiment: 17
# Experiment: 18
# Experiment: 19
# Experiment: 20
# Experiment: 21
# Experiment: 22
# Experiment: 23
# Experiment: 24
# Experiment: 25
# Experiment: 26
# Experiment: 27
# Experiment: 28
# Experiment: 29
# Experiment: 30
