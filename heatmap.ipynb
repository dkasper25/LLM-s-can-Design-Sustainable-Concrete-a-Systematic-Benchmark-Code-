# %%
# %run utils/Plot_heatmap.ipynb
# Out:
# Select(description='Select:', layout=Layout(height='200px', width='600px'), options=(('gpt-3.5-turbo', 'Ternar…
# Button(description='Plot', style=ButtonStyle())
# Number of experiments: 14
# 280
